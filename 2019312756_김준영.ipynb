# %%
def isHappy(n):
    sum=0
    happy=n
    while True:
        for i in str(happy):
            sum+=int(i)**2

        if sum==1 or sum==7:
            return True

        if sum<10:
            return False

        happy=sum
        sum=0
